# %%
from IPython.html.widgets.interact import interact, interactive
from IPython.display import clear_output, display, HTML

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Basic interact

# %%
def show_args(**kwargs):
    s = '<h3>Arguments:</h3><table>\n'
    for k,v in kwargs.items():
        s += '<tr><td>{0}</td><td>{1}</td></tr>\n'.format(k,v)
    s += '</table>'
    display(HTML(s))

# %%
interact(show_args, Temp=(0,10), Current=(0.,10.,0.01), z=(True,False),
         b=u'initial value',
         Algorithm=['This','That','Other'])
# Out:
# <h3>Arguments:</h3><table>
# <tr><td>Current</td><td>3.84</td></tr>
# <tr><td>z</td><td>True</td></tr>
# <tr><td>b</td><td>initial value</td></tr>
# <tr><td>Temp</td><td>5</td></tr>
# <tr><td>Algorithm</td><td>This</td></tr>
# </table>

# %% [markdown]
# ## Factoring polynomials

# %%
from sympy import Symbol, Eq, factor, init_printing
init_printing(use_latex=True)

# %%
x = Symbol('x')

# %%
def factorit(n):
    display(Eq(x**n-1, factor(x**n-1)))

# %%
interact(factorit, n=(2,40))
# Out:
#  18                       ⎛ 2        ⎞ ⎛ 2        ⎞ ⎛ 6    3    ⎞ ⎛ 6    3
# x   - 1 = (x - 1)⋅(x + 1)⋅⎝x  - x + 1⎠⋅⎝x  + x + 1⎠⋅⎝x  - x  + 1⎠⋅⎝x  + x  + 1
#
# ⎞
# ⎠

# %% [markdown]
# ## A simple image browser

# %%
from sklearn import datasets

# %%
digits = datasets.load_digits()

# %%
def browse_images(digits):
    n = len(digits.images)
    def view_image(i):
        imshow(digits.images[i], cmap=cm.gray_r, interpolation='nearest')
        title('Training: %s' % digits.target[i])
        show()
    interact(view_image, i=(0,n-1))

# %%
browse_images(digits)

# %% [markdown]
# ## Explore random graphs

# %%
import networkx as nx

# %%
def plot_random_graph(n, p, generator):
    f = getattr(nx, generator)
    g = f(n,p)
    nx.draw(g)
    show()

# %%
interact(plot_random_graph, n=(2,30), p=(0.0, 1.0, 0.001),
        generator=('gnp_random_graph','erdos_renyi_graph','binomial_graph'))

# %% [markdown]
# ## Image manipulation

# %%
import skimage
from skimage import data, filter, io

# %%
i = data.coffee()

# %%
io.Image(i)
# Out:
# Image([[[ 21,  13,   8],
#         [ 21,  13,   9],
#         [ 20,  11,   8],
#         ...,
#         [228, 182, 138],
#         [231, 185, 142],
#         [228, 184, 140]],
#
#        [[ 21,  13,   7],
#         [ 21,  13,   9],
#         [ 20,  14,   7],
#         ...,
#         [228, 182, 136],
#         [231, 185, 139],
#         [229, 183, 137]],
#
#        [[ 21,  14,   7],
#         [ 23,  13,  10],
#         [ 20,  14,   9],
#         ...,
#         [228, 182, 136],
#         [228, 184, 137],
#         [229, 185, 138]],
#
#        ...,
#        [[189, 124,  77],
#         [214, 155, 109],
#         [197, 141, 100],
#         ...,
#         [165,  86,  37],
#         [161,  82,  41],
#         [143,  67,  29]],
#
#        [[207, 148, 102],
#         [201, 142,  99],
#         [196, 140,  97],
#         ...,
#         [154,  74,  37],
#         [147,  66,  33],
#         [145,  65,  31]],
#
#        [[197, 141, 100],
#         [195, 137,  99],
#         [193, 138,  98],
#         ...,
#         [158,  73,  38],
#         [144,  64,  30],
#         [143,  60,  29]]], dtype=uint8)

# %%
def edit_image(image):
    def apply_filter(sigma, r, g, b):
        new_image = filter.gaussian_filter(image, sigma=sigma)
        new_image[:,:,0] = r*new_image[:,:,0]
        new_image[:,:,1] = g*new_image[:,:,1]
        new_image[:,:,2] = b*new_image[:,:,2]
        new_image = io.Image(new_image)
        display(new_image)
        return new_image
    lims = (0.0,1.0,0.01)
    return interactive(apply_filter, sigma=(0.1,10.0,0.01), r=lims, g=lims, b=lims)

# %%
w = edit_image(i)

# %%
display(w)
# Out:
# Image([[[ 0.0411573 ,  0.02547226,  0.01639683],
#         [ 0.0407832 ,  0.02494838,  0.01726023],
#         [ 0.04026606,  0.02431887,  0.01758624],
#         ...,
#         [ 0.44790344,  0.35765822,  0.28169306],
#         [ 0.45013283,  0.36070495,  0.28520085],
#         [ 0.44870556,  0.36083869,  0.28487476]],
#
#        [[ 0.04133743,  0.02583128,  0.01565602],
#         [ 0.04121794,  0.02572717,  0.01712396],
#         [ 0.04058161,  0.02601198,  0.01696156],
#         ...,
#         [ 0.44688354,  0.35661723,  0.2780647 ],
#         [ 0.44966847,  0.36040675,  0.28194067],
#         [ 0.44924285,  0.36071754,  0.28207327]],
#
#        [[ 0.04160298,  0.02628585,  0.01507569],
#         [ 0.0419046 ,  0.02605106,  0.01740773],
#         [ 0.04094023,  0.02635186,  0.0176198 ],
#         ...,
#         [ 0.44616726,  0.3558847 ,  0.27628635],
#         [ 0.44855402,  0.36064286,  0.28110244],
#         [ 0.44960328,  0.3626796 ,  0.28361545]],
#
#        ...,
#        [[ 0.37874164,  0.25720471,  0.17538701],
#         [ 0.39267847,  0.27447749,  0.19419178],
#         [ 0.39365858,  0.27996179,  0.20437925],
#         ...,
#         [ 0.31562484,  0.15554693,  0.07347506],
#         [ 0.30199257,  0.14566865,  0.07106522],
#         [ 0.28869774,  0.13511283,  0.06485144]],
#
#        [[ 0.39298804,  0.27649548,  0.19712603],
#         [ 0.3925631 ,  0.27817893,  0.20178108],
#         [ 0.38765464,  0.27681983,  0.20349604],
#         ...,
#         [ 0.30764062,  0.14727344,  0.0724048 ],
#         [ 0.29452047,  0.13679494,  0.06885448],
#         [ 0.28539235,  0.12862478,  0.06341963]],
#
#        [[ 0.38911582,  0.27712282,  0.20351209],
#         [ 0.38546781,  0.27333149,  0.20203652],
#         [ 0.38251908,  0.27252029,  0.20087598],
#         ...,
#         [ 0.30156042,  0.13867159,  0.06887081],
#         [ 0.28923501,  0.12932534,  0.06525768],
#         [ 0.28242102,  0.12205168,  0.0609927 ]]])

# %%
w.arguments
# Out:
# {b: 0.52, g: 0.5, r: 0.5, sigma: 0.77}

# %%
w.result
# Out:
# Image([[[ 0.0411573 ,  0.02547226,  0.01639683],
#         [ 0.0407832 ,  0.02494838,  0.01726023],
#         [ 0.04026606,  0.02431887,  0.01758624],
#         ...,
#         [ 0.44790344,  0.35765822,  0.28169306],
#         [ 0.45013283,  0.36070495,  0.28520085],
#         [ 0.44870556,  0.36083869,  0.28487476]],
#
#        [[ 0.04133743,  0.02583128,  0.01565602],
#         [ 0.04121794,  0.02572717,  0.01712396],
#         [ 0.04058161,  0.02601198,  0.01696156],
#         ...,
#         [ 0.44688354,  0.35661723,  0.2780647 ],
#         [ 0.44966847,  0.36040675,  0.28194067],
#         [ 0.44924285,  0.36071754,  0.28207327]],
#
#        [[ 0.04160298,  0.02628585,  0.01507569],
#         [ 0.0419046 ,  0.02605106,  0.01740773],
#         [ 0.04094023,  0.02635186,  0.0176198 ],
#         ...,
#         [ 0.44616726,  0.3558847 ,  0.27628635],
#         [ 0.44855402,  0.36064286,  0.28110244],
#         [ 0.44960328,  0.3626796 ,  0.28361545]],
#
#        ...,
#        [[ 0.37874164,  0.25720471,  0.17538701],
#         [ 0.39267847,  0.27447749,  0.19419178],
#         [ 0.39365858,  0.27996179,  0.20437925],
#         ...,
#         [ 0.31562484,  0.15554693,  0.07347506],
#         [ 0.30199257,  0.14566865,  0.07106522],
#         [ 0.28869774,  0.13511283,  0.06485144]],
#
#        [[ 0.39298804,  0.27649548,  0.19712603],
#         [ 0.3925631 ,  0.27817893,  0.20178108],
#         [ 0.38765464,  0.27681983,  0.20349604],
#         ...,
#         [ 0.30764062,  0.14727344,  0.0724048 ],
#         [ 0.29452047,  0.13679494,  0.06885448],
#         [ 0.28539235,  0.12862478,  0.06341963]],
#
#        [[ 0.38911582,  0.27712282,  0.20351209],
#         [ 0.38546781,  0.27333149,  0.20203652],
#         [ 0.38251908,  0.27252029,  0.20087598],
#         ...,
#         [ 0.30156042,  0.13867159,  0.06887081],
#         [ 0.28923501,  0.12932534,  0.06525768],
#         [ 0.28242102,  0.12205168,  0.0609927 ]]])
